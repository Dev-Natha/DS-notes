# %%
# Assignment 3
Collate the following informations for every 36 states in Nigeria.
State Name
State Capital
State Population
State Landmass
Create a Pandas Series object of state population and landmass using state name as the key of both.
From the two Series objects, create a DataFrame object and add the state capital as new collumn to the table.
Calculate the population density of each state and use it to generate a new collumn on the DataFrame object.

# %%
import numpy as np
import pandas as pd

# %%
import pandas as pd
import random

state_names = [
    'Abia', 'Adamawa', 'Akwa Ibom', 'Anambra', 'Bauchi', 'Bayelsa', 'Benue', 'Borno',
    'Cross River', 'Delta', 'Ebonyi', 'Edo', 'Ekiti', 'Enugu', 'Gombe', 'Imo',
    'Jigawa', 'Kaduna', 'Kano', 'Katsina', 'Kebbi', 'Kogi', 'Kwara', 'Lagos',
    'Nasarawa', 'Niger', 'Ogun', 'Ondo', 'Osun', 'Oyo', 'Plateau', 'Rivers', 'Sokoto',
    'Taraba', 'Yobe', 'Zamfara', 'Federal Capital Territory'
]

state_capitals = [
    'Umuahia', 'Yola', 'Uyo', 'Awka', 'Bauchi', 'Yenagoa', 'Makurdi', 'Maiduguri',
    'Calabar', 'Asaba', 'Abakaliki', 'Benin City', 'Ado-Ekiti', 'Enugu', 'Gombe',
    'Owerri', 'Dutse', 'Kaduna', 'Kano', 'Katsina', 'Birnin Kebbi', 'Lokoja', 'Ilorin',
    'Ikeja', 'Lafia', 'Minna', 'Abeokuta', 'Akure', 'Osogbo', 'Ibadan', 'Jos',
    'Port Harcourt', 'Sokoto', 'Jalingo', 'Damaturu', 'Gusau', 'Abuja'
]


state_population = [random.randint(1000000, 30000000) for _ in range(len(state_names))]
state_landmass = [random.randint(5000, 50000) for _ in range(len(state_names))]


population_series = pd.Series(state_population, index=state_names, name='Population')
landmass_series = pd.Series(state_landmass, index=state_names, name='Landmass')


df = pd.DataFrame({'Population': population_series, 'Landmass': landmass_series})


df['State Capital'] = state_capitals


df['Population Density'] = df['Population'] / df['Landmass']

df
# Out:
#                            Population  Landmass  State Capital  \
# Abia                          7276847     19012        Umuahia
# Adamawa                      15527467     24175           Yola
# Akwa Ibom                    12164142     31511            Uyo
# Anambra                      18035237     21394           Awka
# Bauchi                       13618672     11310         Bauchi
# Bayelsa                      25306590     36455        Yenagoa
# Benue                        29298499     13925        Makurdi
# Borno                         6617837     45412      Maiduguri
# Cross River                   1025631     47628        Calabar
# Delta                        13171697     13586          Asaba
# Ebonyi                        2001110     22968      Abakaliki
# Edo                          27838036     37151     Benin City
# Ekiti                        19779928      5626      Ado-Ekiti
# Enugu                        23980059     33569          Enugu
# ...

# %%
clean_car['price'].sum()
clean_car['price'].mean()
# Out:
# 27214291658

# %%
car_scrape = pd.read_csv("C:\\Users\\HP\\Documents\\NUMPY\\Datasets\\car_scrape4.csv")
clean_car = car_scrape.dropna(axis='columns', how='all')
clean_car
# Out:
#                       title  odometer location    isimported          engine  \
# 0            Toyota Corolla     60127    Lagos  Locally used  4-cylinder(I4)
# 1                 Acura MDX    132908    Lagos  Foreign Used  6-cylinder(V6)
# 2              Lexus ES 350    120412    Lagos  Locally used  6-cylinder(V6)
# 3     Mercedes-Benz GLK 350     67640    Lagos  Foreign Used  4-cylinder(I4)
# 4       Mercedes-Benz E 200     92440    Abuja  Foreign Used  4-cylinder(I4)
# ...                     ...       ...      ...           ...             ...
# 3171          Ford Explorer    108597    Abuja  Foreign Used  6-cylinder(V6)
# 3172              Ford Edge    145184    Lagos  Foreign Used  6-cylinder(I6)
# 3173           Toyota Camry     88687    Lagos  Foreign Used  4-cylinder(I4)
# 3174      Toyota Highlander     30951    Lagos  Foreign Used  6-cylinder(V6)
# 3175           Toyota Camry     12936    Lagos  Foreign Used  4-cylinder(I4)
#
# ...

# %%
arr = np.array(clean_car['price'])
arr.min()
# Out:
# 215000

# %%
highest_car = clean_car[clean_car['price'] == arr.max()]
lowest_car = clean_car[clean_car['price'] == arr.min()]
# highest_car
lowest_car
# Out:
#                title  odometer location    isimported          engine  \
# 601  Volkswagen Golf    200000    Abuja  Locally used  4-cylinder(I4)
#
#     transmission    fuel    paint   price  year
# 601       manual  petrol  Silver   215000  1998

# %%
#ASSIGNMENT 4
# Using the datasets above: List_of_local_governments_in_Nigeria.csv and Nigeria_povertyrate_per_local_gov.csv
#     1. Merge the dataset together to form a single table.
#     2. Remove any redundant columns.
#     3. Calculate how population affects poverty rate of each local government.
#     4. Arrange each local government accordiing to the order of their poverty rate.
#     5. Find the percentage of poverty and sort in ascending order.
LGN = pd.read_csv("C:\\Users\\HP\\Documents\\DATASCIENCE\\Dataset\\Nigeria data\\list_of_local_government_areas_of_nigeria.csv")
NPR = pd.read_csv("C:\\Users\\HP\\Documents\\DATASCIENCE\\Dataset\\Nigeria data\\Nigeria povertyrate per local gov.csv")
NPR.tail(100)
# Out:
#      ID_0  ISO   NAME_0  ID_12    State  SNo        NAME_23  2014_Popul  \
# 675   163  NGA  Nigeria     32  Plateau  676         Mikang      106046
# 676   163  NGA  Nigeria     32  Plateau  677       Pankshin      196240
# 677   163  NGA  Nigeria     32  Plateau  678       Qua'anpa      221252
# 678   163  NGA  Nigeria     32  Plateau  679          Riyom      154546
# 679   163  NGA  Nigeria     32  Plateau  680        Shendam      251442
# ..    ...  ...      ...    ...      ...  ...            ...         ...
# 770   163  NGA  Nigeria     38  Zamfara  771           Maru      449533
# 771   163  NGA  Nigeria     38  Zamfara  772       Shinkafi      220070
# 772   163  NGA  Nigeria     38  Zamfara  773  Talata-Mafara      131298
# 773   163  NGA  Nigeria     38  Zamfara  774          Tsafe      333706
# 774   163  NGA  Nigeria     38  Zamfara  775          Zurmi      291140
#
#      Poverty_Ra  2014_Pover
# 675    0.548764       59476
# 676    0.413344       80788
# ...

# %%
LGN['State'] = LGN['State'].str.replace("State", "")
LGN.head()
# Out:
#   SNo Local Government Area       State
# 0   1                Abadam      Borno
# 1   2                 Abaji         FCT
# 2   3                  Abak  Akwa Ibom
# 3   4             Abakaliki     Ebonyi
# 4   5             Aba North       Abia

# %%
merge_data = pd.merge(LGN, NPR, how="inner", left_on="Local Government Area", right_on="NAME_23")
merge_data
# Out:
#     SNo_x Local Government Area     State_x  ID_0  ISO   NAME_0  ID_12  \
# 0       1                Abadam      Borno    163  NGA  Nigeria      8
# 1       2                 Abaji         FCT   163  NGA  Nigeria     15
# 2       3                  Abak  Akwa Ibom    163  NGA  Nigeria      3
# 3       5             Aba North       Abia    163  NGA  Nigeria      1
# 4       6             Aba South       Abia    163  NGA  Nigeria      1
# ..    ...                   ...         ...   ...  ...      ...    ...
# 590   769                 Zango    Katsina    163  NGA  Nigeria     21
# 591   771                 Zaria     Kaduna    163  NGA  Nigeria     19
# 592   772                  Zing     Taraba    163  NGA  Nigeria     35
# 593   773                 Zurmi    Zamfara    163  NGA  Nigeria     38
# 594   774                  Zuru      Kebbi    163  NGA  Nigeria     22
#
#                        State_y  SNo_y    NAME_23  2014_Popul  Poverty_Ra  \
# ...

# %%
merge_data.drop(["NAME_23", "Unnamed: 3", "Unnamed: 10", "NAME_12", "NAME_0", "ID_0"], axis=1, inplace=True)
merge_data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1120\570775038.py in <module>
# ----> 1 merge_data.drop(["NAME_23", "Unnamed: 3", "Unnamed: 10", "NAME_12", "NAME_0", "ID_0"], axis=1, inplace=True)
#       2 merge_data
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ...

# %%
# correlation = merge_data.corr(method = "pearson")
# correlation
cor = merge_data["2014_Popul"].corr(merge_data["Poverty_Ra"])
cor
# Out:
# -0.17341719641294773

# %%
sort_loc = merge_data.sort_values(by=["Poverty_Ra"], ascending=True)
sort_loc
# Out:
#     SNo_x Local Government Area  State_x  ID_0  ISO   NAME_0  ID_12 State_y  \
# 161   221                 Fagge    Kano    163  NGA  Nigeria     20    Kano
# 524   685          Sokoto North  Sokoto    163  NGA  Nigeria     34  Sokoto
# 567   737                 Uvwie   Delta    163  NGA  Nigeria     10   Delta
# 3       5             Aba North    Abia    163  NGA  Nigeria      1    Abia
# 77    105                  Bida   Niger    163  NGA  Nigeria     27   Niger
# ..    ...                   ...      ...   ...  ...      ...    ...     ...
# 438   576              Ohaozara  Ebonyi    163  NGA  Nigeria     11  Ebonyi
# 159   219            Ezza North  Ebonyi    163  NGA  Nigeria     11  Ebonyi
# 439   577               Ohaukwu  Ebonyi    163  NGA  Nigeria     11  Ebonyi
# 160   220            Ezza South  Ebonyi    163  NGA  Nigeria     11  Ebonyi
# 245   337                  Ikwo  Ebonyi    163  NGA  Nigeria     11  Ebonyi
#
# ...

# %%
sort_loc["2014_Pover"] = sort_loc["2014_Pover"] / 100
sort_loc
# Out:
#     SNo_x Local Government Area  State_x  ID_0  ISO   NAME_0  ID_12 State_y  \
# 161   221                 Fagge    Kano    163  NGA  Nigeria     20    Kano
# 524   685          Sokoto North  Sokoto    163  NGA  Nigeria     34  Sokoto
# 567   737                 Uvwie   Delta    163  NGA  Nigeria     10   Delta
# 3       5             Aba North    Abia    163  NGA  Nigeria      1    Abia
# 77    105                  Bida   Niger    163  NGA  Nigeria     27   Niger
# ..    ...                   ...      ...   ...  ...      ...    ...     ...
# 438   576              Ohaozara  Ebonyi    163  NGA  Nigeria     11  Ebonyi
# 159   219            Ezza North  Ebonyi    163  NGA  Nigeria     11  Ebonyi
# 439   577               Ohaukwu  Ebonyi    163  NGA  Nigeria     11  Ebonyi
# 160   220            Ezza South  Ebonyi    163  NGA  Nigeria     11  Ebonyi
# 245   337                  Ikwo  Ebonyi    163  NGA  Nigeria     11  Ebonyi
#
# ...

# %%
# Assignment 5
# import Califonial_cities dataset and perform the following activities on it:
# 1. Clean the data by getting rid of every null values
# 2. make cities column an index
# 3. describe the dataset
# 4. extract the city with highest population total, highest area land square meter and area water square meter
# 5. calculate the total area total square meter of Californian city
# 6. calculate the sum of the dataset along column axis

cal_cty = pd.read_csv("C:\\Users\\HP\\Documents\\NUMPY\\Datasets\\california_cities.csv")
cal_cty.head(100)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1120\188165907.py in <module>
#       8 # 6. calculate the sum of the dataset along column axis
#       9
# ---> 10 cal_cty = pd.read_csv("C:\\Users\\HP\\Documents\\NUMPY\\Datasets\\california_cities.csv")
#      11 cal_cty.head(100)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
# cal_cty.drop(["Unnamed: 14", "Unnamed: 15"], inplace=True, axis=1)
cal_cty = cal_cty.fillna(0)
cal_cty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 482 entries, 0 to 481
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          482 non-null    int64
#  1   city                482 non-null    object
#  2   latd                482 non-null    float64
#  3   longd               482 non-null    float64
#  4   elevation_m         482 non-null    float64
#  5   elevation_ft        482 non-null    float64
#  6   population_total    482 non-null    int64
#  7   area_total_sq_mi    482 non-null    float64
#  8   area_land_sq_mi     482 non-null    float64
#  9   area_water_sq_mi    482 non-null    float64
#  10  area_total_km2      482 non-null    float64
#  11  area_land_km2       482 non-null    float64
#  12  area_water_km2      482 non-null    float64
#  13  area_water_percent  482 non-null    float64
# dtypes: float64(11), int64(2), object(1)
# memory usage: 52.8+ KB

# %%
# cal_cty = cal_cty.set_index(cal_cty.city)
# cal_cty.drop(["Unnamed: 0", "city"], inplace=True, axis=1)
cal_cty.describe()
# Out:
#              latd       longd  elevation_m  elevation_ft  population_total  \
# count  482.000000  482.000000   482.000000    482.000000      4.820000e+02
# mean    36.095088 -119.837714   162.449896    553.048340      6.489493e+04
# std      2.298006    2.147676   298.619572    992.646622      2.032041e+05
# min     32.578333 -124.263333   -34.000000   -180.000000      1.000000e+00
# 25%     33.977292 -121.954931    15.250000     62.000000      1.090200e+04
# 50%     36.204722 -119.708611    50.500000    182.000000      2.905750e+04
# 75%     37.886667 -117.977292   151.000000    502.500000      6.646650e+04
# max     41.965000 -114.596389  2402.000000   7880.000000      3.884307e+06
#
#        area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  area_total_km2  \
# count        482.000000       482.000000        482.000000      482.000000
# mean          18.365660        16.840981          1.586332       46.268290
# ...

# %%
cal_pop = np.array(cal_cty.population_total)
cal_pop.max()
highest_cty =cal_cty[cal_cty.population_total == cal_pop.max()]
highest_cty

# cal_as = np.array(cal_cty.area_land_sq_mi)
# cal_as.max()
hal = cal_cty[cal_cty.area_land_sq_mi == 469.000000]
hal

haw = cal_cty[cal_cty.area_water_sq_mi == 185.020000]
haw
# Out:
#                    latd       longd  elevation_m  elevation_ft  \
# city
# SanFrancisco  37.783333 -122.416667          0.0          52.0
#
#               population_total  area_total_sq_mi  area_land_sq_mi  \
# city
# SanFrancisco            837442            231.89            46.87
#
#               area_water_sq_mi  area_total_km2  area_land_km2  area_water_km2  \
# city
# SanFrancisco            185.02             0.0            0.0             0.0
#
#               area_water_percent
# city
# SanFrancisco                80.0

# %%
cal_cty.sum()
# Out:
# latd                  1.739783e+04
# longd                -5.776178e+04
# elevation_m           7.830085e+04
# elevation_ft          2.665693e+05
# population_total      3.127936e+07
# area_total_sq_mi      8.852248e+03
# area_land_sq_mi       8.117353e+03
# area_water_sq_mi      7.646120e+02
# area_total_km2        2.230132e+04
# area_land_km2         2.081548e+04
# area_water_km2        1.493835e+03
# area_water_percent    2.528959e+03
# dtype: float64

# %%
# Assignment 6

# Using the Melbourne_housing_FULL.csv

# Extract for the dataset where price column is not null into another variable
# Based on the new variable, clean the data to ensure no more NAN on the dataset by applyiing the following:
# Delete unuseful columns from the dataset
# Use the number of rooms column to fill the missing number of Bedroom2
# Use the number of Bedroom2 to fill th missing number of Bathroom
# Using this same logic, look for a column that have close relationship with another column with missing number and use it to fill for the missing values in the column
# Show in a table, how Bedroom2 and landsize affect the price of the house.
# Also, show how BuildingArea and Yearbuit affect the price of the house
# In table1, show the sum and median of the price of house based on Bedroom2.

# %%
melb = pd.read_csv("C:\\Users\\HP\\Documents\\NUMPY\\Datasets\\Melbourne_housing_FULL.csv")
# melb.info()
melb
# Out:
#            Suburb             Address  Rooms Type      Price Method  \
# 0      Abbotsford       68 Studley St      2    h        NaN     SS
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S
# 2      Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4      Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...           ...                 ...    ...  ...        ...    ...
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI
# 34853  Yarraville       29A Murray St      2    h   888000.0     SP
# 34854  Yarraville      147A Severn St      2    t   705000.0      S
# 34855  Yarraville    12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville    3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis   3/09/2016       2.5    3067.0  ...       1.0  1.0
# ...

# %%
mel_price = melb.Price.dropna()
mel_price = melb[melb["Price"].notnull()]
mel_price
# Out:
#            Suburb           Address  Rooms Type      Price Method  \
# 1      Abbotsford      85 Turner St      2    h  1480000.0      S
# 2      Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 4      Abbotsford      5 Charles St      3    h  1465000.0     SP
# 5      Abbotsford  40 Federation La      3    h   850000.0     PI
# 6      Abbotsford       55a Park St      4    h  1600000.0     VB
# ...           ...               ...    ...  ...        ...    ...
# 34852  Yarraville       13 Burns St      4    h  1480000.0     PI
# 34853  Yarraville     29A Murray St      2    h   888000.0     SP
# 34854  Yarraville    147A Severn St      2    t   705000.0      S
# 34855  Yarraville  12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville  3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 1             Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0
# ...

# %%
# mel_price.drop(["Type", "Lattitude", "Longtitude"], inplace=True, axis=1)
mel_price.Bedroom2.fillna(mel_price.Rooms, inplace=True)
mel_price.Bathroom.fillna(mel_price.Bedroom2, inplace=True)
mel_price.head(100)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12760\1399251577.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mel_price.Bedroom2.fillna(mel_price.Rooms, inplace=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_12760\1399251577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mel_price.Bathroom.fillna(mel_price.Bedroom2, inplace=True)
#            Suburb           Address  Rooms      Price Method SellerG  \
# 1      Abbotsford      85 Turner St      2  1480000.0      S  Biggin
# 2      Abbotsford   25 Bloomburg St      2  1035000.0      S  Biggin
# ...

# %%
mel_price.Landsize.fillna(mel_price.Landsize.mean(), inplace=True)
mel_price.BuildingArea.fillna(mel_price.BuildingArea.mean(), inplace=True)
mel_price.Car.fillna(mel_price.Car.mean(), inplace=True)
mel_price.YearBuilt.fillna(0, inplace=True)
mel_price
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12760\4019668917.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mel_price.Landsize.fillna(mel_price.Landsize.mean(), inplace=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_12760\4019668917.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mel_price.BuildingArea.fillna(mel_price.BuildingArea.mean(), inplace=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_12760\4019668917.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# correlation = mel_price.corr(method = "pearson")
# correlation
# bil_cor = mel_price[['Bedroom2', 'Landsize', 'Price']].corr()
# bil_cor
# bil_cor1 = mel_price[['BuildingArea', 'YearBuilt', 'Price']].corr()
# bil_cor1
# Out:
#               BuildingArea  YearBuilt     Price
# BuildingArea      1.000000  -0.018393  0.066514
# YearBuilt        -0.018393   1.000000  0.031785
# Price             0.066514   0.031785  1.000000

# %%
# roomprice_mean = mel_price.groupby('Bedroom2')['Price'].mean()
# roomprice_mean
roomprice_sum = mel_price.groupby('Bedroom2')['Price'].sum()
roomprice_sum
# Out:
# Bedroom2
# 0.0     1.648350e+07
# 1.0     5.325307e+08
# 2.0     5.270359e+09
# 3.0     1.235486e+10
# 4.0     7.994413e+09
# 5.0     2.118505e+09
# 6.0     2.421160e+08
# 7.0     3.528350e+07
# 8.0     1.833002e+07
# 9.0     5.841000e+06
# 10.0    1.329000e+07
# 12.0    5.410000e+06
# 16.0    5.000000e+06
# 20.0    1.650000e+06
# Name: Price, dtype: float64

# %%
# Out:
#    Unnamed: 0  ID                           Title  Year  Age  IMDb  \
# 0           0   1                       Inception  2010  13+   8.8
# 1           1   2                      The Matrix  1999  18+   8.7
# 2           2   3          Avengers: Infinity War  2018  13+   8.5
# 3           3   4              Back to the Future  1985   7+   8.5
# 4           4   5  The Good, the Bad and the Ugly  1966  18+   8.8
#
#    Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  \
# 0             87.0        1     0            0        0
# 1             87.0        1     0            0        0
# 2             84.0        1     0            0        0
# 3             96.0        1     0            0        0
# 4             97.0        1     0            1        0
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# 1  Lana Wachowski,Lilly Wachowski                     Action,Sci-Fi
# ...
